# %% [markdown]
# # Likes Report
# ## Jake Berman
# ### 9/21/21

# %%
import pandas as pd
import json
import matplotlib as plt

# %% [markdown]
# ## 1

# %%
with open(r"/Users/jake/Downloads/jake___berman_20210907/likes/liked_posts.json") as p:
                dat = json.load(p)

# %% [markdown]
# ## 2

# %%
dat.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %%
dat['likes_media_likes']
# Out:
# [{'title': 'failsvines',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1UIHKjQKpS/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432325377}]},
#  {'title': 'kevinhart4real',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2-2EJvCYuH/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432297034}]},
#  {'title': 'hilarrious',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/287iWvs5yW/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432228669}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1oPhNwJuYd/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432123489}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/11rEXypua2/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432123456}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2E59-ZpuaE/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432123445}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2wcVztJuT4/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432123285}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/21z2xsJudE/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432123261}]},
#  {'title': 'studentchills',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/25vPzYREH1/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432123213}]},
#  {'title': 'daquan',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/24uLPflXkU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432087935}]},
#  {'title': 'besthoodhumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/224jQkGsRx5eAxq5T6xHlzx_TttRbsncK55MM0/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432035849}]},
#  {'title': 'studentchills',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2s7B1-REAs/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432003705}]},
#  {'title': 'studentchills',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2il85HRENF/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432003676}]},
#  {'title': 'studentchills',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/12yhyzREDD/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432003662}]},
#  {'title': 'studentchills',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1hVXO5xEGR/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432003657}]},
#  {'title': 'studentchills',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1qW246REF2/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1432003650}]},
#  {'title': 'jordanmaron',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/21gGOkkEFf/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431979543}]},
#  {'title': 'fail.daily',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/21gMmELH0n/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431979484}]},
#  {'title': 'redneckvideos',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/20q5REh9xa/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431951522}]},
#  {'title': 'jeffdunham',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2w4T1QpZN-/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431824316}]},
#  {'title': 'theantvenom',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2w3bDwMsJe/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431823833}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/qLhQMoKuw5/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779722}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/qdlSndKu1L/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779714}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/qvpHdwKu02/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779704}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/rRIre2KuxH/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779685}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/spZwy-qu2y/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779640}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/wyVd9Hqu6Z/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779498}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/xD-q9Gquxv/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779482}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/xJmGtnKuzg/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779472}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/xbSePfKu_k/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779452}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/x9RHRZKu_7/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779432}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/yO_BESKu0s/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779399}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/xqtIE7Ku_3/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779319}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/zFPG3FKu75/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779301}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/zWu7kTqu7G/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779281}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/zouVOAKu93/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779276}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/z7kWMXquzF/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779267}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/0NTCUqKu8X/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779252}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/0eymk_quzZ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779233}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/0w0GSfKu75/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779216}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1DLPjiqux6/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779205}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1VG4bBKu3U/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779180}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/10I4OBKux3/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779173}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/18BabbKuzY/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779165}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2LTezzquwe/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779152}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2Qem2WKu0I/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779138}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2damQ1quwC/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779125}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2f3uWQKu1l/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779113}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2npxg8quyj/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779103}]},
#  {'title': 'shockinghumor',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2vbbiDqu-V/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431779093}]},
#  {'title': 'oofdynasty',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2u0UHCHceB/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431778723}]},
#  {'title': 'gizzygazza',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2u1iROh0FL/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431778611}]},
#  {'title': 'daquan',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2u6gdWlXh7/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431778553}]},
#  {'title': 'daquan',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2vIJLflXhR/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431778391}]},
#  {'title': 'epicfunnypage',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2vVtIBmu-O/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431778364}]},
#  {'title': 'lulz',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1Dc4NWGaQB/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431726984}]},
#  {'title': 'lulz',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1VecFFGaeK/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431726970}]},
#  {'title': 'lulz',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1YEUFhmaZM/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431726962}]},
#  {'title': 'lulz',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1qIuYomaZ6/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431726956}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2HMJzQJue3/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431721958}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2Rqw0WpuTP/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431721943}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2Ue8vVpubZ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431721932}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2WqIoUpuRY/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431721908}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2b5WEFJudo/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431721889}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2ecN76JuaM/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431721868}]},
#  {'title': 'all.things.ball',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2rXgGfpuW_/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1431
/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434634420}]},
#  {'title': 'datboytatted60',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/3_7LWLqJ0F/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434569188}]},
#  {'title': 'one.minute.videos',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/3_MPfgHvpt/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434466564}]},
#  {'title': 'one.minute.videos',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/3_Mn2qHvqD/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434466560}]},
#  {'title': 'illusionfeeds',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/3_Vv1zPYFa/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434466226}]},
#  {'title': 'studentchills',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/3_gw9dxEBp/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434466125}]},
#  {'title': 'earldibblesjr',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/3_js3SNF-9/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434465870}]},
#  {'title': 'feelsworthy',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/3_j0GNr6Ao/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434465845}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/z3g1zJzXVu/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402534}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/z4RCR3TXev/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402517}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/0EhAC8zXb-/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402507}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/0Q9YfXzXUi/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402486}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/0V28U4TXZg/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402472}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/0bh0DyzXQB/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402453}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/0eY1M3zXRQ/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402423}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/0ocRcUzXSh/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402404}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/0tRaZfTXVd/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402378}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/08--rnzXfU/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402361}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1GVoONzXRk/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402346}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1H2zhzzXWd/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402325}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1LRUR6TXXk/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402306}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1QfHkjzXUz/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402300}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1WVUI4zXX0/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402258}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1Yx3HYTXew/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402246}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1YUwjIzXVp/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402229}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1enh9EzXeW/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402192}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1m5mMQzXSF/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402176}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1v4CbnzXUv/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402150}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1y1G7bTXR0/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402136}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/12RppYTXRD/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402119}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/16NXSjTXRb/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402047}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/141jfsTXWj/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402031}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/2DFQAcTXRm/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434402009}]},
#  {'title': 'vidyocliips',
#   'media_list_data': [],
#   'string_list_data': [{'href': 'https://www.instagram.com/p/1-xm3HzXeT/',
#     'value': 'ð\x9f\x91\x8d',
#     'timestamp': 1434401986}]},
#  ...]

# %%
df_likes = pd.DataFrame(dat['likes_media_likes'])

# %%
df_likes
# Out:
#                                 title media_list_data  \
# 0                          failsvines              []
# 1                      kevinhart4real              []
# 2                          hilarrious              []
# 3                     all.things.ball              []
# 4                     all.things.ball              []
# ...                               ...             ...
# 11065                           memes              []
# 11066                            lulz              []
# 11067                           funny              []
# 11068  3.1415926535897932384626433832              []
# 11069                            snag              []
#
#                                         string_list_data
# 0      [{'href': 'https://www.instagram.com/p/1UIHKjQ...
# 1      [{'href': 'https://www.instagram.com/p/2-2EJvC...
# 2      [{'href': 'https://www.instagram.com/p/287iWvs...
# 3      [{'href': 'https://www.instagram.com/p/1oPhNwJ...
# 4      [{'href': 'https://www.instagram.com/p/11rEXyp...
# ...                                                  ...
# 11065  [{'href': 'https://www.instagram.com/p/Ba7FB9Q...
# 11066  [{'href': 'https://www.instagram.com/p/Ba5MzhB...
# 11067  [{'href': 'https://www.instagram.com/p/Ba5oB51...
# 11068  [{'href': 'https://www.instagram.com/p/Ba5fGsd...
# 11069  [{'href': 'https://www.instagram.com/p/Ba699tr...
#
# [11070 rows x 3 columns]

# %%
string_list_data = [x['title'] for x in dat['likes_media_likes']]

# %%
string_list_data
# Out:
# ['failsvines',
#  'kevinhart4real',
#  'hilarrious',
#  'all.things.ball',
#  'all.things.ball',
#  'all.things.ball',
#  'all.things.ball',
#  'all.things.ball',
#  'studentchills',
#  'daquan',
#  'besthoodhumor',
#  'studentchills',
#  'studentchills',
#  'studentchills',
#  'studentchills',
#  'studentchills',
#  'jordanmaron',
#  'fail.daily',
#  'redneckvideos',
#  'jeffdunham',
#  'theantvenom',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'oofdynasty',
#  'gizzygazza',
#  'daquan',
#  'daquan',
#  'epicfunnypage',
#  'lulz',
#  'lulz',
#  'lulz',
#  'lulz',
#  'all.things.ball',
#  'all.things.ball',
#  'all.things.ball',
#  'all.things.ball',
#  'all.things.ball',
#  'all.things.ball',
#  'all.things.ball',
#  'all.things.ball',
#  'wave.tv',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'crainer',
#  'lulz',
#  'one.minute.videos',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'daquan',
#  'hood_videos',
#  'besthoodhumor',
#  'dongslap',
#  'earldibblesjr',
#  'earldibblesjr',
#  'earldibblesjr',
#  'earldibblesjr',
#  'earldibblesjr',
#  'earldibblesjr',
#  'kyliejennerlipvideos',
#  'kyliejennerlipvideos',
#  'oofdynasty',
#  'skilltwins',
#  'skilltwins',
#  'skilltwins',
#  'skilltwins',
#  'skilltwins',
#  'skilltwins',
#  'bestcliips',
#  'bestcliips',
#  'bestcliips',
#  'bestcliips',
#  'bestcliips',
#  'bitching',
#  'one.minute.videos',
#  'studentchills',
#  'studentchills',
#  'studentchills',
#  'studentchills',
#  'randomvideos',
#  'randomvideos',
#  'randomvideos',
#  'randomvideos',
#  'pubertyhits',
#  'pubertyhits',
#  'pubertyhits',
#  'feelsworthy',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'alphasportz',
#  'bitching',
#  'dumbfactsig',
#  'besthoodhumor',
#  'besthoodhumor',
#  'vikkstagram',
#  'besthoodhumor',
#  'besthoodhumor',
#  'feelsworthy',
#  'feelsworthy',
#  'besthoodhumor',
#  'horoscoptic',
#  'feelsworthy',
#  'feelsworthy',
#  'tobuscus',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'horoscoptic',
#  'lulz',
#  'daquan',
#  'lulz',
#  'lulz',
#  'lulz',
#  'lulz',
#  'lulz',
#  'lulz',
#  'lulz',
#  'lulz',
#  'horoscoptic',
#  'oofdynasty',
#  'besthoodhumor',
#  'hilarrious',
#  'horoscoptic',
#  'besthoodhumor',
#  'one.minute.videos',
#  'jchockey5',
#  'bitching',
#  'kingbach',
#  'gizzygazza',
#  'icomedytexting',
#  'hilarrious',
#  'daquan',
#  'lmao',
#  'lulz',
#  'lulz',
#  'lulz',
#  'lulz',
#  'jeffdunham',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'officialclevelandsports',
#  'oofdynasty',
#  'craziestfunnypage',
#  'horoscoptic',
#  'dumbfactsig',
#  'dumbfactsig',
#  'dumbfactsig',
#  'dumbfactsig',
#  'dumbfactsig',
#  'dumbfactsig',
#  'dumbfactsig',
#  'dumbfactsig',
#  'besthoodhumor',
#  'horoscoptic',
#  'daquan',
#  'steph_clavin',
#  'steph_clavin',
#  'hidden_little_leaf_4_life',
#  'hidden_little_leaf_4_life',
#  'hidden_little_leaf_4_life',
#  'hilarrious',
#  'alphahouseguys',
#  'alphahouseguys',
#  'alphahouseguys',
#  'nba',
#  'nba',
#  'nba',
#  'icomedytexting',
#  'horoscoptic',
#  'hilarrious',
#  'pubertyhits',
#  'oofdynasty',
#  'cliphero',
#  'tobuscus',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'fail.daily',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'daquan',
#  'fail.daily',
#  'daquan',
#  'daquan',
#  'cakeguide',
#  'fail.daily',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'lmao',
#  'hilarrious',
#  'hilarrious',
#  'jeromeaceti',
#  'craziestfunnypage',
#  'hilarrious',
#  'hilarrious',
#  'hilarrious',
#  'hilarrious',
#  'hilarrious',
#  'hilarrious',
#  'icomedytexting',
#  'daquan',
#  'daquan',
#  'theycallmejerry',
#  'rademita',
#  'rademita',
#  'rademita',
#  'rademita',
#  'rademita',
#  'dongslap',
#  'jeromeaceti',
#  'pewdiepie',
#  'jordonking_21',
#  'jordonking_21',
#  'dongslap',
#  'zerkaa',
#  'kevinhart4real',
#  'fail.daily',
#  'dongslap',
#  'icomedytexting',
#  'dongslap',
#  'dongslap',
#  'craziestfunnypage',
#  'fail.daily',
#  'fail.daily',
#  'fail.daily',
#  'fail.daily',
#  'dongslap',
#  'dongslap',
#  'dongslap',
#  'icomedytexting',
#  'dongslap',
#  'cliphero',
#  'officialclevelandsports',
#  'icomedytexting',
#  'dongslap',
#  'dongslap',
#  'slyfoxbabyshambles',
#  'icomedytexting',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'dongslap',
#  'crainer',
#  'ohcomedypics',
#  'dongslap',
#  'dongslap',
#  'dongslap',
#  'kingbach',
#  'icomedytexting',
#  'ohcomedypics',
#  'dongslap',
#  'dongslap',
#  'dongslap',
#  'dongslap',
#  'icomedytexting',
#  'kingjames',
#  'icomedytexting',
#  'kevinhart4real',
#  'dongslap',
#  'ohcomedypics',
#  'dongslap',
#  'icomedytexting',
#  'dongslap',
#  'icomedytexting',
#  'ohcomedypics',
#  'dongslap',
#  'dongslap',
#  'dongslap',
#  'icomedytexting',
#  'tiffyquake',
#  'ohcomedypics',
#  'chargecords',
#  'ohcomedypics',
#  'ohcomedypics',
#  'doyougame',
#  'ubisoft',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'ricardo_c67',
#  'ricardo_c67',
#  'ricardo_c67',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'tobuscus',
#  'icomedytexting',
#  'jeffdunham',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'that_one_crazy_boy_',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'that_one_crazy_boy_',
#  'icomedytexting',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'icomedytexting',
#  'wizzofficial_',
#  'icomedytexting',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'meloniemac',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'ohcomedypics',
#  'ohcomedypics',
#  'ohcomedypics',
#  'icomedytexting',
#  'that_one_crazy_boy_',
#  'that_one_crazy_boy_',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'logdotzip',
#  'meloniemac',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'kingjames',
#  'kevinhart4real',
#  'icomedytexting',
#  'icomedytexting',
#  'icomedytexting',
#  'syndicate',
#  'icomedytexting',
#  'icomedytexting',
#  'wizzofficial_',
#  'prestonplayz',
#  'icomedytexting',
#  'icomedytexting',
#  'family_guy_vids__',
#  'officialclevelandsports',
#  'meloniemac',
#  'laublau24',
#  'laublau24',
#  'icomedytexting',
#  'laublau24',
#  'icomedytexting',
#  'reversedworlds',
#  'reversedworlds',
#  'daily_wtf_facts',
#  'daily_wtf_facts',
#  'daily_wtf_facts',
#  'daily_wtf_facts',
#  'daily_wtf_facts',
#  'daily_wtf_facts',
#  'daily_wtf_facts',
#  'daily_wtf_facts',
#  'daily_wtf_facts',
#  'daily_wtf_facts',
#  'daily_wtf_facts',
#  'videospost.s',
#  'videospost.s',
#  'videospost.s',
#  'official_ajc',
#  'icomedytexting',
#  'icomedytexting',
#  'syndicate',
#  'wizzofficial_',
#  'tobuscus',
#  'logdotzip',
#  'wizzofficial_',
#  'jayswagkid13',
#  'jeromeaceti',
#  'prestonplayz',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'mackenzieewbu',
#  'ryan_kitay',
#  'logdotzip',
#  'logrock',
#  'officialclevelandsports',
#  'tobuscus',
#  'laughsandinventions',
#  'officialclevelandsports',
#  'officialclevelandsports',
#  'jackwillard_',
#  'ohio_florida',
#  'tiffyquake',
#  'likewhenyouseenit',
#  'likewhenyouseenit',
#  'chriistina_clarkk',
#  'lydia_and_justin',
#  'lydia_and_justin',
#  'lydia_and_justin',
#  'lydia_and_justin',
#  'lydia_and_justin',
#  'bestttextt',
#  'its_lydia_and_ya_know_it',
#  'its_lydia_and_ya_know_it',
#  'its_lydia_and_ya_know_it',
#  'its_lydia_and_ya_know_it',
#  'slyfoxbabyshambles',
#  'slyfoxbabyshambles',
#  'slyfoxbabyshambles',
#  'princess_josh',
#  'princess_josh',
#  'relatabled',
#  'relatabled',
#  'relatabled',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'shockinghumor',
#  'littlelizardgaming',
#  'fact',
#  'fact',
#  'fact',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'punnstagram',
#  'hood_videos',
#  'hood_videos',
#  'hood_videos',
#  'hood_videos',
#  'hood_videos',
#  'hood_videos',
#  'hood_videos',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'wild.video',
#  'dongslap',
#  'dunk',
#  'dunk',
#  'dunk',
#  'dunk',
#  'dunk',
#  'dunk',
#  'dunk',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'bitchy',
#  'public.pranks',
#  'public.pranks',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'woahgame',
#  'woahgame',
#  'daquan',
#  'fact',
#  'fact',
#  'wild.video',
#  'besthoodhumor',
#  'gizzygazza',
#  'comedycentral',
#  'dongslap',
#  'wild.video',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'oofdynasty',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'feelsworthy',
#  'wild.video',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'horoscoptic',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'learn',
#  'video.media',
#  'kingbach',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'stupidplays',
#  'theantvenom',
#  'hilarrious',
#  'freestyler.max',
#  'freestyler.max',
#  'freestyler.max',
#  'freestyler.max',
#  'freestyler.max',
#  'best.today',
#  'best.today',
#  'best.today',
#  'best.today',
#  'hoodviideos',
#  'hoodviideos',
#  'hoodviideos',
#  'hoodviideos',
#  'hoodviideos',
#  'hoodviideos',
#  'hoodviideos',
#  'wild.video',
#  'hurdles',
#  'hurdles',
#  'hurdles',
#  'hurdles',
#  'hurdles',
#  'hurdles',
#  'hurdles',
#  'hurdles',
#  'hurdles',
#  'hurdles',
#  'hurdles',
#  'hurdles',
#  'hilarrious',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'bars',
#  'batmanarkham',
#  'datboytatted60',
#  'one.minute.videos',
#  'one.minute.videos',
#  'illusionfeeds',
#  'studentchills',
#  'earldibblesjr',
#  'feelsworthy',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  'vidyocliips',
#  ...]

# %%
df_likes2 = pd.DataFrame(string_list_data)

# %%
df_likes2
# Out:
#                                     0
# 0                          failsvines
# 1                      kevinhart4real
# 2                          hilarrious
# 3                     all.things.ball
# 4                     all.things.ball
# ...                               ...
# 11065                           memes
# 11066                            lulz
# 11067                           funny
# 11068  3.1415926535897932384626433832
# 11069                            snag
#
# [11070 rows x 1 columns]

# %%
df_likes2.to_csv(r"/Users/jake/Downloads/Filename.csv", encoding = "utf-8")

# %% [markdown]
# ## 4

# %%
df_likes2.groupby(string_list_data).count()
# Out:
#                                   0
# 100picsquiz                       3
# 2.718281828459045235360287420     1
# 24viral                           1
# 2nbamemes                         4
# 3.1415926535897932384626433832  339
# ...                             ...
# yt.cougarr                        1
# zachking                        175
# zak_harrison                      2
# zee.pyro                          1
# zerkaa                            1
#
# [728 rows x 1 columns]

# %% [markdown]
# ## 3

# %% [markdown]
# A) The data was collected from Instagram.
# B) One reason why Instagram collects data is for advertisers.
# C) The data is reliable because it is just tracking posts liked from my account.
# D) The data may be unreliable because

# %%
timestamp = [x['string_list_data'][0]['timestamp'] for x in dat['likes_media_likes']]

# %%
timestamp
# Out:
# [1432325377,
#  1432297034,
#  1432228669,
#  1432123489,
#  1432123456,
#  1432123445,
#  1432123285,
#  1432123261,
#  1432123213,
#  1432087935,
#  1432035849,
#  1432003705,
#  1432003676,
#  1432003662,
#  1432003657,
#  1432003650,
#  1431979543,
#  1431979484,
#  1431951522,
#  1431824316,
#  1431823833,
#  1431779722,
#  1431779714,
#  1431779704,
#  1431779685,
#  1431779640,
#  1431779498,
#  1431779482,
#  1431779472,
#  1431779452,
#  1431779432,
#  1431779399,
#  1431779319,
#  1431779301,
#  1431779281,
#  1431779276,
#  1431779267,
#  1431779252,
#  1431779233,
#  1431779216,
#  1431779205,
#  1431779180,
#  1431779173,
#  1431779165,
#  1431779152,
#  1431779138,
#  1431779125,
#  1431779113,
#  1431779103,
#  1431779093,
#  1431778723,
#  1431778611,
#  1431778553,
#  1431778391,
#  1431778364,
#  1431726984,
#  1431726970,
#  1431726962,
#  1431726956,
#  1431721958,
#  1431721943,
#  1431721932,
#  1431721908,
#  1431721889,
#  1431721868,
#  1431721851,
#  1431721844,
#  1431721823,
#  1431721787,
#  1431721773,
#  1431721732,
#  1431721700,
#  1431721678,
#  1431721663,
#  1431721596,
#  1431692453,
#  1431691978,
#  1431691970,
#  1431649741,
#  1431649733,
#  1431649708,
#  1431649679,
#  1431649664,
#  1431649647,
#  1431649641,
#  1431649630,
#  1431649597,
#  1431649584,
#  1431649546,
#  1431649534,
#  1431649532,
#  1431649506,
#  1431649426,
#  1431649231,
#  1431606006,
#  1431605705,
#  1431605678,
#  1431605661,
#  1431605651,
#  1431605615,
#  1431605583,
#  1431605569,
#  1431547508,
#  1431547502,
#  1431517733,
#  1431461231,
#  1431461164,
#  1431461131,
#  1431461112,
#  1431461079,
#  1431461037,
#  1431430416,
#  1431430384,
#  1431430349,
#  1431430330,
#  1431430321,
#  1431379513,
#  1431344509,
#  1431299866,
#  1431299857,
#  1431299851,
#  1431299838,
#  1431299813,
#  1431299797,
#  1431299780,
#  1431299771,
#  1431280494,
#  1431280490,
#  1431280403,
#  1431199339,
#  1431130606,
#  1431130601,
#  1431130591,
#  1431130560,
#  1431130542,
#  1431130537,
#  1431130515,
#  1431130500,
#  1431130468,
#  1431115574,
#  1431115551,
#  1431115474,
#  1431115460,
#  1431115384,
#  1431115339,
#  1431115281,
#  1431115159,
#  1431115068,
#  1431115056,
#  1431115000,
#  1431114906,
#  1431114823,
#  1431114817,
#  1431114788,
#  1431114714,
#  1431087702,
#  1431087677,
#  1431087672,
#  1431087665,
#  1431087645,
#  1431087636,
#  1431087605,
#  1431087596,
#  1431087588,
#  1431087569,
#  1431087548,
#  1431087523,
#  1431087471,
#  1431087430,
#  1431087307,
#  1431047536,
#  1431047410,
#  1431047406,
#  1431047400,
#  1431047384,
#  1431047371,
#  1431047365,
#  1431047357,
#  1431047348,
#  1431001125,
#  1431001098,
#  1431001033,
#  1430829308,
#  1430829283,
#  1430829260,
#  1430829036,
#  1430827749,
#  1430770222,
#  1430740024,
#  1430739955,
#  1430739896,
#  1430702850,
#  1430605737,
#  1430576760,
#  1430520638,
#  1430520624,
#  1430520568,
#  1430520372,
#  1430514945,
#  1430510698,
#  1430510690,
#  1430510677,
#  1430510656,
#  1430510651,
#  1430510629,
#  1430510615,
#  1430510609,
#  1430510596,
#  1430510497,
#  1430510481,
#  1430510470,
#  1430510451,
#  1430510438,
#  1430510429,
#  1430510390,
#  1430510361,
#  1430510350,
#  1430510324,
#  1430510280,
#  1430510263,
#  1430510251,
#  1430510193,
#  1430510149,
#  1430510139,
#  1430480782,
#  1430480724,
#  1430480690,
#  1430480620,
#  1430480502,
#  1430480485,
#  1430480474,
#  1430480460,
#  1430480448,
#  1430480436,
#  1430480417,
#  1430480407,
#  1430480325,
#  1430436684,
#  1430435525,
#  1430425419,
#  1430425415,
#  1430185207,
#  1430185170,
#  1430185156,
#  1430136617,
#  1429926586,
#  1429926581,
#  1429926575,
#  1429836099,
#  1429836043,
#  1429836036,
#  1429791371,
#  1429791252,
#  1429704293,
#  1429704209,
#  1429704118,
#  1429645983,
#  1429568591,
#  1429559501,
#  1429559444,
#  1429559426,
#  1429559371,
#  1429559365,
#  1429559358,
#  1429559356,
#  1429559343,
#  1429559335,
#  1429559329,
#  1429559309,
#  1429559157,
#  1429532592,
#  1429532478,
#  1429532451,
#  1429532436,
#  1429328551,
#  1429301312,
#  1429062471,
#  1429062421,
#  1429048599,
#  1429048349,
#  1429047998,
#  1429047975,
#  1429047971,
#  1429047936,
#  1429047923,
#  1429047914,
#  1429047908,
#  1429047882,
#  1429047867,
#  1429047850,
#  1429047797,
#  1429047771,
#  1429047757,
#  1429047753,
#  1429047730,
#  1429047725,
#  1429047687,
#  1429047681,
#  1429047670,
#  1429047643,
#  1429047633,
#  1429047607,
#  1429047599,
#  1429047589,
#  1429047544,
#  1429047508,
#  1429047495,
#  1429047469,
#  1429047460,
#  1429047392,
#  1429047364,
#  1429013382,
#  1429013166,
#  1428927525,
#  1428927508,
#  1428927446,
#  1428927435,
#  1428927425,
#  1428927392,
#  1428927220,
#  1428891587,
#  1428891538,
#  1428891278,
#  1428891236,
#  1428891226,
#  1428891180,
#  1428891158,
#  1428891101,
#  1428880835,
#  1428805543,
#  1428786812,
#  1428779171,
#  1428779049,
#  1428775075,
#  1428774965,
#  1428774876,
#  1428771246,
#  1428762146,
#  1428762068,
#  1428762058,
#  1428761947,
#  1428756497,
#  1428714585,
#  1428708249,
#  1428708239,
#  1428708209,
#  1428695384,
#  1428695374,
#  1428695304,
#  1428668683,
#  1428611946,
#  1428611782,
#  1428581734,
#  1428581706,
#  1428581595,
#  1428581579,
#  1428581537,
#  1428581365,
#  1428536858,
#  1428536832,
#  1428536808,
#  1428536783,
#  1428536774,
#  1428536766,
#  1428536747,
#  1428536740,
#  1428536734,
#  1428536728,
#  1428536709,
#  1428536700,
#  1428536685,
#  1428536673,
#  1428536661,
#  1428536651,
#  1428536634,
#  1428536622,
#  1428536612,
#  1428536606,
#  1428536593,
#  1428536576,
#  1428536564,
#  1428536549,
#  1428536479,
#  1428536462,
#  1428536436,
#  1428536419,
#  1428536413,
#  1428536409,
#  1428536395,
#  1428494694,
#  1428494541,
#  1428494464,
#  1428494433,
#  1428494413,
#  1428494370,
#  1428494293,
#  1428494112,
#  1428371576,
#  1428268521,
#  1428268437,
#  1428268288,
#  1428080767,
#  1427995156,
#  1427995140,
#  1427971782,
#  1427663738,
#  1427663247,
#  1427552201,
#  1427552155,
#  1427312984,
#  1427312840,
#  1427199193,
#  1427153678,
#  1427140421,
#  1427140400,
#  1427073521,
#  1426966030,
#  1426818542,
#  1426818494,
#  1426806000,
#  1426803689,
#  1426802856,
#  1426772270,
#  1426456419,
#  1426432960,
#  1426161612,
#  1426075824,
#  1425989691,
#  1425567377,
#  1425567354,
#  1425567311,
#  1425475051,
#  1425416344,
#  1425388639,
#  1425302062,
#  1424831229,
#  1424819118,
#  1424784722,
#  1424294225,
#  1423789453,
#  1423789278,
#  1423695654,
#  1423573227,
#  1423573110,
#  1423228403,
#  1422767567,
#  1422717996,
#  1422623904,
#  1422623892,
#  1422623783,
#  1422511737,
#  1422274664,
#  1422250479,
#  1422210231,
#  1422136334,
#  1422063472,
#  1421985660,
#  1421805185,
#  1421805164,
#  1421805120,
#  1421805062,
#  1421731418,
#  1421730982,
#  1421730973,
#  1421703685,
#  1421703592,
#  1421567226,
#  1421567213,
#  1421567156,
#  1421567102,
#  1421567093,
#  1421567077,
#  1421567062,
#  1421566995,
#  1421566989,
#  1421557961,
#  1421557945,
#  1421469864,
#  1421410464,
#  1421205216,
#  1421080909,
#  1421018849,
#  1421018837,
#  1421018750,
#  1420993459,
#  1420925853,
#  1420925850,
#  1420909708,
#  1420909680,
#  1420906362,
#  1420842211,
#  1420808931,
#  1420779471,
#  1420664331,
#  1420587102,
#  1420463814,
#  1420243600,
#  1420006974,
#  1419968212,
#  1419534254,
#  1419460508,
#  1419452394,
#  1419201601,
#  1418736482,
#  1418736477,
#  1418736298,
#  1418736294,
#  1418214190,
#  1418213760,
#  1418213615,
#  1418177919,
#  1418177752,
#  1417817615,
#  1417401663,
#  1417401636,
#  1416883629,
#  1416789311,
#  1416610957,
#  1416230872,
#  1415367245,
#  1414463059,
#  1410551887,
#  1406602508,
#  1402574814,
#  1402574812,
#  1401407296,
#  1401407278,
#  1401407270,
#  1401407261,
#  1401407244,
#  1401407241,
#  1401407159,
#  1401407152,
#  1401407126,
#  1401365763,
#  1400588877,
#  1400188328,
#  1400188288,
#  1400188177,
#  1398282743,
#  1397245567,
#  1397218489,
#  1396899840,
#  1396818776,
#  1396798899,
#  1395515171,
#  1395085544,
#  1394488303,
#  1394392956,
#  1393334076,
#  1390596650,
#  1390596642,
#  1390596638,
#  1390596637,
#  1390596635,
#  1390596633,
#  1390596632,
#  1390596630,
#  1390596628,
#  1390596625,
#  1390596623,
#  1390596622,
#  1390596619,
#  1390596617,
#  1390596615,
#  1390596614,
#  1390596608,
#  1390596605,
#  1390596604,
#  1390596603,
#  1390596601,
#  1390596600,
#  1388099585,
#  1384347170,
#  1381595158,
#  1381595082,
#  1380065971,
#  1373580800,
#  1373311296,
#  1372562725,
#  1368215031,
#  1367171098,
#  1366805173,
#  1364950909,
#  1364950837,
#  1362356219,
#  1360934559,
#  1360934544,
#  1360934535,
#  1360934533,
#  1360934531,
#  1352753406,
#  1349143530,
#  1349143407,
#  1348487879,
#  1348230071,
#  1341342408,
#  1340069431,
#  1338293673,
#  1338233777,
#  1337084388,
#  1436043143,
#  1436043136,
#  1436043125,
#  1436039357,
#  1436039350,
#  1436039343,
#  1436039326,
#  1436039317,
#  1436039306,
#  1436039290,
#  1436015979,
#  1435973012,
#  1435972853,
#  1435972800,
#  1435962010,
#  1435961999,
#  1435961989,
#  1435961966,
#  1435961959,
#  1435961925,
#  1435961875,
#  1435961864,
#  1435961844,
#  1435961827,
#  1435961809,
#  1435961791,
#  1435961775,
#  1435961760,
#  1435961739,
#  1435961725,
#  1435877391,
#  1435859724,
#  1435859711,
#  1435859694,
#  1435859690,
#  1435859667,
#  1435859639,
#  1435859599,
#  1435799689,
#  1435799671,
#  1435799630,
#  1435799592,
#  1435799540,
#  1435799531,
#  1435799514,
#  1435799501,
#  1435799474,
#  1435799442,
#  1435799430,
#  1435799414,
#  1435799260,
#  1435799231,
#  1435799219,
#  1435799196,
#  1435799182,
#  1435799168,
#  1435799127,
#  1435799070,
#  1435799061,
#  1435799048,
#  1435799043,
#  1435759267,
#  1435687174,
#  1435684565,
#  1435682753,
#  1435682739,
#  1435682659,
#  1435682641,
#  1435682537,
#  1435598615,
#  1435598599,
#  1435598589,
#  1435598540,
#  1435598527,
#  1435598397,
#  1435598385,
#  1435598353,
#  1435598326,
#  1435598300,
#  1435598291,
#  1435598266,
#  1435598259,
#  1435598253,
#  1435598247,
#  1435598242,
#  1435598239,
#  1435598233,
#  1434935933,
#  1434935805,
#  1434935747,
#  1434935733,
#  1434935710,
#  1434935685,
#  1434935633,
#  1434935573,
#  1434894974,
#  1434745684,
#  1434745663,
#  1434745615,
#  1434745608,
#  1434745596,
#  1434745557,
#  1434745552,
#  1434745545,
#  1434745526,
#  1434745521,
#  1434745516,
#  1434745503,
#  1434745493,
#  1434745477,
#  1434745463,
#  1434745454,
#  1434745443,
#  1434745432,
#  1434745420,
#  1434745407,
#  1434745389,
#  1434745378,
#  1434745357,
#  1434745342,
#  1434745329,
#  1434745321,
#  1434745297,
#  1434745290,
#  1434745272,
#  1434745262,
#  1434745255,
#  1434745251,
#  1434745234,
#  1434745224,
#  1434745218,
#  1434745200,
#  1434745194,
#  1434745164,
#  1434745146,
#  1434745137,
#  1434745120,
#  1434745103,
#  1434745094,
#  1434745076,
#  1434745060,
#  1434745050,
#  1434745032,
#  1434745026,
#  1434745015,
#  1434745003,
#  1434744993,
#  1434744980,
#  1434744970,
#  1434744953,
#  1434744930,
#  1434744918,
#  1434744910,
#  1434744897,
#  1434744882,
#  1434744869,
#  1434744856,
#  1434744847,
#  1434744837,
#  1434744824,
#  1434744815,
#  1434744798,
#  1434744792,
#  1434744786,
#  1434744732,
#  1434744718,
#  1434744700,
#  1434744694,
#  1434744657,
#  1434744646,
#  1434744626,
#  1434744609,
#  1434744599,
#  1434744584,
#  1434744577,
#  1434744570,
#  1434634420,
#  1434569188,
#  1434466564,
#  1434466560,
#  1434466226,
#  1434466125,
#  1434465870,
#  1434465845,
#  1434402534,
#  1434402517,
#  1434402507,
#  1434402486,
#  1434402472,
#  1434402453,
#  1434402423,
#  1434402404,
#  1434402378,
#  1434402361,
#  1434402346,
#  1434402325,
#  1434402306,
#  1434402300,
#  1434402258,
#  1434402246,
#  1434402229,
#  1434402192,
#  1434402176,
#  1434402150,
#  1434402136,
#  1434402119,
#  1434402047,
#  1434402031,
#  1434402009,
#  1434401986,
#  ...]

# %%
df_likes2['timestamp'] = timestamp

# %%
df_likes2
# Out:
#                                     0   timestamp
# 0                          failsvines  1432325377
# 1                      kevinhart4real  1432297034
# 2                          hilarrious  1432228669
# 3                     all.things.ball  1432123489
# 4                     all.things.ball  1432123456
# ...                               ...         ...
# 11065                           memes  1509477757
# 11066                            lulz  1509475499
# 11067                           funny  1509475411
# 11068  3.1415926535897932384626433832  1509475408
# 11069                            snag  1509475388
#
# [11070 rows x 2 columns]

# %% [markdown]
# ## 5

# %% [markdown]
# ## Theoretical Hypothesis
#
# a) I think that in the information about you folder the ads interests file will have unreliable data/have a bunch of ads that are of no interest to the user.
#
# b) The ideal data for the hypothesis would be a file of all the ads clicked on by the user.

# %% [markdown]
# ## Statistical Hypothesis
#
# a)I think 90% of my the accounts from my liked posts will be from meme acounts.
#
# b)The ideal data for the hypothesis would just be a statistic of the accounts from my liked posts to show what type of account they are.
#
# number of likes

# %% [markdown]
# ## 7
# The source of the data used was from Instagram. The structure of that data was in the form of lists.
